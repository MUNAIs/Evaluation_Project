# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head(10)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5  93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6  87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7  81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8  80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9  78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86
# 5  34   88
# 6  48   93
# ...

# %%
df.tail(5)
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no null value in this dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
def pplot(df,i):
    plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
sns.histplot(x=i,data=df,kde=True,bins=10)
plt.subplot(1,3,2)
sns.regplot(x=i,y='E',data=df)
plt.subplot(1,3,3)
sns.boxplot(y=i,data=df)
plt.show()

# %%
df.hist( bins = 20, figsize = (20,20))
plt.show()

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(df['R'], ax = axs[0])
plt2 = sns.boxplot(df['AB'], ax = axs[1])
plt3 = sns.boxplot(df['2B'], ax = axs[2])

plt.tight_layout()

# %% [markdown]
# There is some outliers in R and E columns

# %%
df.drop('E',axis=1,inplace=True)

# %% [markdown]
# There is no relation between target variable and E and have outliers so we drop it

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.drop('BB',axis=1,inplace=True)

# %%
df.drop('3B',axis=1,inplace=True)

# %%
df.drop('RA',axis=1,inplace=True)

# %%
df.drop('SV',axis=1,inplace=True)

# %%
df.drop('SB',axis=1,inplace=True)

# %% [markdown]
# These columns are not corelated with W so we drop it

# %%
df
# Out:
#       W    R    AB     H   2B   HR    SO   ER   ERA  CG  SHO
# 0    95  724  5575  1497  300  139   973  601  3.73   2    8
# 1    83  696  5467  1349  277  156  1264  653  4.07   2   12
# 2    81  669  5439  1395  303  141  1157  584  3.67  11   10
# 3    76  622  5533  1381  260  136  1231  643  3.98   7    9
# 4    74  689  5605  1515  289  151  1259  746  4.64   7   12
# 5    93  891  5509  1480  308  232  1151  609  3.80   7   10
# 6    87  764  5567  1397  272  212  1227  652  4.03   3    4
# 7    81  713  5485  1370  246  217  1331  646  4.05   0   10
# 8    80  644  5485  1383  278  167  1310  604  3.74   1   12
# 9    78  748  5640  1495  294  161  1148  694  4.31   3   10
# 10   88  751  5511  1419  279  172  1233  680  4.24   5    9
# 11   86  729  5459  1363  278  230  1392  572  3.57   5   13
# 12   85  661  5417  1331  243  176  1150  630  3.94   2   12
# 13   76  656  5544  1379  262  198  1336  677  4.16   6   12
# ...

# %% [markdown]
# # Remove the skewness of my dataset

# %%
x=df.drop('W', axis=1)
y=df['W']

# %%
x
# Out:
#       R    AB     H   2B   HR    SO   ER   ERA  CG  SHO
# 0   724  5575  1497  300  139   973  601  3.73   2    8
# 1   696  5467  1349  277  156  1264  653  4.07   2   12
# 2   669  5439  1395  303  141  1157  584  3.67  11   10
# 3   622  5533  1381  260  136  1231  643  3.98   7    9
# 4   689  5605  1515  289  151  1259  746  4.64   7   12
# 5   891  5509  1480  308  232  1151  609  3.80   7   10
# 6   764  5567  1397  272  212  1227  652  4.03   3    4
# 7   713  5485  1370  246  217  1331  646  4.05   0   10
# 8   644  5485  1383  278  167  1310  604  3.74   1   12
# 9   748  5640  1495  294  161  1148  694  4.31   3   10
# 10  751  5511  1419  279  172  1233  680  4.24   5    9
# 11  729  5459  1363  278  230  1392  572  3.57   5   13
# 12  661  5417  1331  243  176  1150  630  3.94   2   12
# 13  656  5544  1379  262  198  1336  677  4.16   6   12
# 14  694  5600  1405  277  146  1119  664  4.14   5   15
# 15  647  5484  1386  288  137  1267  478  2.94   1   15
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
x.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# HR     0.516441
# SO    -0.156065
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %%
type(x_new)
# Out:
# numpy.ndarray

# %%
x.columns
# Out:
# Index(['R', 'AB', 'H', '2B', 'HR', 'SO', 'ER', 'ERA', 'CG', 'SHO'], dtype='object')

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x
# Out:
#       R   AB    H        2B        HR        SO        ER       ERA        CG  \
# 0   0.0  0.0  0.0  1.477685 -0.764626 -2.569896 -0.497425 -0.500893 -0.359844
# 1   0.0  0.0  0.0  0.084269 -0.158581  0.134913  0.257974  0.261806 -0.359844
# 2   0.0  0.0  0.0  1.670782 -0.689676 -0.901254 -0.746906 -0.636459  1.993513
# 3   0.0  0.0  0.0 -0.848600 -0.879049 -0.189628  0.113575  0.060804  1.220103
# 4   0.0  0.0  0.0  0.792183 -0.329850  0.085459  1.582654  1.520959  1.220103
# 5   0.0  0.0  0.0  1.998506  1.937860 -0.957960 -0.380464 -0.343110  1.220103
# 6   0.0  0.0  0.0 -0.198558  1.460099 -0.228668  0.243552  0.172549  0.064630
# 7   0.0  0.0  0.0 -1.556454  1.583551  0.807174  0.156937  0.217193 -1.729889
# 8   0.0  0.0  0.0  0.141687  0.200058  0.594561 -0.453532 -0.478328 -0.909181
# 9   0.0  0.0  0.0  1.099405  0.007404 -0.986257  0.845910  0.794823  0.064630
# 10  0.0  0.0  0.0  0.199390  0.355503 -0.170084  0.645876  0.639800  0.716445
# ...

# %%
x.skew()
# Out:
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# HR    -0.000065
# SO     0.041170
# ER    -0.001940
# ERA    0.001746
# CG    -0.059785
# SHO    0.006560
# dtype: float64

# %%
sk=x.skew()

# %%
sk
# Out:
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# HR    -0.000065
# SO     0.041170
# ER    -0.001940
# ERA    0.001746
# CG    -0.059785
# SHO    0.006560
# dtype: float64

# %%
np.abs(3)
# Out:
# 3

# %%
sk[np.abs(sk)>0.5].all()
# Out:
# True

# %% [markdown]
# There is no skewness in this dataset

# %% [markdown]
# Remove outliers

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 11)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       W    R    AB     H   2B   HR    SO   ER   ERA  CG  SHO
# 0    95  724  5575  1497  300  139   973  601  3.73   2    8
# 1    83  696  5467  1349  277  156  1264  653  4.07   2   12
# 2    81  669  5439  1395  303  141  1157  584  3.67  11   10
# 3    76  622  5533  1381  260  136  1231  643  3.98   7    9
# 4    74  689  5605  1515  289  151  1259  746  4.64   7   12
# 6    87  764  5567  1397  272  212  1227  652  4.03   3    4
# 7    81  713  5485  1370  246  217  1331  646  4.05   0   10
# 8    80  644  5485  1383  278  167  1310  604  3.74   1   12
# 9    78  748  5640  1495  294  161  1148  694  4.31   3   10
# 10   88  751  5511  1419  279  172  1233  680  4.24   5    9
# 11   86  729  5459  1363  278  230  1392  572  3.57   5   13
# 12   85  661  5417  1331  243  176  1150  630  3.94   2   12
# 13   76  656  5544  1379  262  198  1336  677  4.16   6   12
# 14   68  694  5600  1405  277  146  1119  664  4.14   5   15
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (30, 11)
# (29, 11)

# %%
loss_percent=((30-29)/30)*100
print(loss_percent)
# Out:
# 3.3333333333333335

# %% [markdown]
# # Model Building

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression 
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.8315598393943253

# %%
X=df.iloc[:,1:14]
y=df['W']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=540)

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
pred=lr.predict(X_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 1.6981097261228417
# MSE: 4.51513208290211
# RMSE: 2.124884016341153

# %%
plt.scatter(x=y_test,y=pred)

# %% [markdown]
# # DecisionTree

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(X_train,y_train)
pred=dtr.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 5.166666666666667
# MSE: 33.833333333333336
# RMSE: 5.816642788871716

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
pred=rf.predict(X_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 3.604999999999999
# MSE: 16.83904999999999
# RMSE: 4.1035411536866535

# %% [markdown]
# rmse value is low in linear model so we choose it

# %%
import pickle
filename='baseball.pkl'
pickle.dump(lr,open(filename,'wb'))
